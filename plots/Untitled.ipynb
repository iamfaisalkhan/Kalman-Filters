# %%
import numpy as np
import matplotlib.pyplot as plt

get_ipython().magic('matplotlib inline')
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['axes.titlesize'] = 8


get_ipython().magic('load_ext autoreload')
get_ipython().magic('autoreload 2')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mu, sigma = 0, 3

x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='red', alpha=0.75)

plt.show()

# %%
n2, bin2, patches2 = plt.hist(np.arctan(x), 50, normed=1, facecolor='blue', alpha=0.75)
plt.axis([-10, 10, 0.00, 0.9])
plt.show()

# %%
n
# Out:
# array([ 0.00021636,  0.        ,  0.00021636,  0.00086543,  0.00064907,
#         0.00086543,  0.00237993,  0.00389443,  0.00475986,  0.00627436,
#         0.00951971,  0.012116  ,  0.01947214,  0.02509743,  0.03548257,
#         0.04089149,  0.04954578,  0.06490713,  0.07788856,  0.08957185,
#         0.10558227,  0.11834734,  0.12137634,  0.1337087 ,  0.13803584,
#         0.13652134,  0.12635256,  0.12635256,  0.12353991,  0.11055849,
#         0.09216813,  0.0746432 ,  0.07009971,  0.05798371,  0.04500228,
#         0.03548257,  0.03093907,  0.02315021,  0.01730857,  0.01038514,
#         0.00951971,  0.00389443,  0.00281264,  0.00173086,  0.0015145 ,
#         0.00064907,  0.00043271,  0.00021636,  0.00043271,  0.00021636])

# %%
x = np.linspace(-10, 10)
y = np.arctan(x)

plt.plot(x, y, x, x)
plt.axhline(0, color='red')
plt.axvline(0, color='red')

plt.show()

# %%
x =np.linspace(-10, 10)
plt.plot(x, np.exp(x))
plt.show()

# %%
plot()
